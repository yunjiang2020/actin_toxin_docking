# %%
import pandas as pd
from sklearn.model_selection import GroupKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
clash = pd.read_csv("clash_readout.csv")
train_df = clash[clash["IS_NEG_CONTROL"] == 0].copy() #only train on barbed-end toxins

# %%
agg = (                            #one input per toxin
    train_df
    .groupby(["toxin", "receptor_state", "box_type"], as_index=False)
    .agg(
        vina_score_best=("vina_score", "min"),
        self_clash_med_06=("self_clash_0.6", "median"),
        self_clash_max_04=("self_clash_0.4", "max"),
        incoming_clash_med_06=("incoming_clash_0.6", "median"),
        incoming_clash_max_06=("incoming_clash_0.6", "max"),
        label=("IS_BLOCKER", "max"),
    )
)

# %%
feats = pd.read_csv("ligand_features_with_flags.csv")
# Out:
#            Name                                             SMILES  valid  \
# 0            2c  [H]C(N(CC)/C=C/[C@@H](C)[C@@H](OC)[C@@H](C)[C@...   True
# 1            2a  O=C([C@@H]1OCCC1)O[C@H](CC[C@H](C)[C@@H](OC)C[...   True
# 2            2u  O=C([C@@H]1OCCC1)O[C@H](CC[C@H](C)[C@@H](OC)C[...   True
# 3  Swinholide_A  C[C@@H]1O[C@H](C[C@@H](C1)OC)CC[C@@H]([C@H](O)...   True
# 4  Aplyronine_A  C[C@@H]1CC[C@@H](/C(=C/C[C@H](C[C@H](/C=C/C[C@...   True
#
#     cLogP    TPSA  HBD  HBA       MW  RotB  Rings  ...  FracCSP3  \
# 0   5.633   91.37    0    7   541.77    20      0  ...     0.833
# 1   4.485  126.62    1    9   598.82    22      1  ...     0.844
# 2   4.094  126.62    1    9   584.80    21      1  ...     0.839
# 3  10.108  288.28    8   20  1389.89    16      5  ...     0.821
# 4   7.736  200.14    2   16  1076.46    23      1  ...     0.746
#
#    Lipinski_violations  Flag_high_cLogP  Flag_high_TPSA  Flag_high_RotB  \
# 0                    2             True           False            True
# 1                    1            False           False            True
# 2                    1            False           False            True
# 3                    4             True            True            True
# 4                    3             True            True            True
#
#    Flag_high_MW  Flag_low_MW  Flag_any  Flag_Category  \
# 0         False        False      True    TooFlexible
# 1         False        False      True    TooFlexible
# 2         False        False      True    TooFlexible
# 3          True        False      True      VeryLarge
# 4          True        False      True      VeryLarge
#
#                                         Flag_Reasons
# 0  too_flexible;too_hydrophobic_cLogP;lipinski_vi...
# 1                                       too_flexible
# 2                                       too_flexible
# 3  very_large_MW;too_flexible;too_polar_TPSA;too_...
# 4  very_large_MW;too_flexible;too_polar_TPSA;too_...
#
# [5 rows x 21 columns]

# %%
feats = feats.rename(columns={"Name": "toxin"})
data = agg.merge(feats, on="toxin", how="left")
# Out:
#           toxin receptor_state box_type  vina_score_best  self_clash_med_06  \
# 0            2a         AMPPNP    TIGHT             -5.3                0.0
# 1            2c         AMPPNP    TIGHT             -5.7                0.0
# 2            2u         AMPPNP    TIGHT             -5.5                0.0
# 3  Aplyronine_A         AMPPNP    TIGHT             -5.3                0.0
# 4  Bistramide_A         AMPPNP    TIGHT             -7.0                0.0
#
#    self_clash_max_04  incoming_clash_med_06  incoming_clash_max_06  label  \
# 0                  2                  226.0                    232      1
# 1                  0                  201.0                    207      1
# 2                  0                  220.0                    228      1
# 3                  0                  261.0                    358      1
# 4                  0                  241.0                    241      1
#
#                                               SMILES  ...  FracCSP3  \
# 0  O=C([C@@H]1OCCC1)O[C@H](CC[C@H](C)[C@@H](OC)C[...  ...     0.844
# 1  [H]C(N(CC)/C=C/[C@@H](C)[C@@H](OC)[C@@H](C)[C@...  ...     0.833
# 2  O=C([C@@H]1OCCC1)O[C@H](CC[C@H](C)[C@@H](OC)C[...  ...     0.839
# 3  C[C@@H]1CC[C@@H](/C(=C/C[C@H](C[C@H](/C=C/C[C@...  ...     0.746
# 4  C/C=C/C(=O)C[C@H]1CC[C@@H]([C@@H](O1)CC(=O)NC[...  ...     0.825
#
#    Lipinski_violations  Flag_high_cLogP  Flag_high_TPSA  Flag_high_RotB  \
# 0                    1            False           False            True
# 1                    2             True           False            True
# 2                    1            False           False            True
# 3                    3             True            True            True
# 4                    2             True            True            True
#
#    Flag_high_MW  Flag_low_MW  Flag_any  Flag_Category  \
# 0         False        False      True    TooFlexible
# 1         False        False      True    TooFlexible
# 2         False        False      True    TooFlexible
# 3          True        False      True      VeryLarge
# 4          True        False      True      VeryLarge
#
#                                         Flag_Reasons
# 0                                       too_flexible
# 1  too_flexible;too_hydrophobic_cLogP;lipinski_vi...
# 2                                       too_flexible
# 3  very_large_MW;too_flexible;too_polar_TPSA;too_...
# 4  very_large_MW;too_flexible;too_polar_TPSA;too_...
#
# [5 rows x 29 columns]

# %%
potency = pd.read_csv("cell_potency.csv")
potency = potency.rename(columns={"Name": "toxin"})
data_train = data.merge(potency, on="toxin", how="left")

# %%
X_cols = [
    "vina_score_best",
    "self_clash_med_06", "self_clash_max_04",
    "incoming_clash_med_06", "incoming_clash_max_06",
    "MW", "cLogP", "TPSA", "HBD", "HBA", "RotB", "Rings", "FracCSP3",
]
X = data_train[X_cols]

# %%
data_train["IS_POTENT"] = (data_train["CELL_POTENCY"] < 2).astype(int) #potent = 1  if IC50 < 100 nM

# %%
y = data_train[["IS_POTENT"]].values.ravel()

# %%
groups = data_train["toxin"]
cv = GroupKFold(n_splits=min(5, data_train["toxin"].nunique()))

# %%
model = Pipeline([
    ("scaler", StandardScaler()),
    ("clf", LogisticRegression(
        penalty="l2",
        class_weight="balanced",
        max_iter=500
    ))
])

scores = cross_val_score(
    model, X, y,
    cv=cv,
    groups=groups,
    scoring="roc_auc"
)

# %%
print("Grouped ROC-AUC:", scores.mean(), "+/-", scores.std())
# Out:
# Grouped ROC-AUC: 0.9 +/- 0.20000000000000004
